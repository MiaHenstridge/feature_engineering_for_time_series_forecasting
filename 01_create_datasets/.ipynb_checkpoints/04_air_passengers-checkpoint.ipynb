# %% [markdown]
# # Air Passengers Dataset
# In this notebook we will prepare and store the air passengers dataset found here.
#
# Citation:
#
# Box, G. E. P., Jenkins, G. M. and Reinsel, G. C. (1976) Time Series Analysis, Forecasting and Control. Third Edition. Holden-Day. Series G.
#
# ## Description of data:
#
# The data is a monthly time series measuring the number of international airline passengers, in thousands, from 1949 to 1960.
#
# In this notebook we will:
#
# Provide instructions to download the air passengers data set
#
# Save the time series data in the correct location for use in the course
#
# ## Get the dataset
# The dataset can be obtained from this link. It will open a raw file in GitHub. A simple way of obtaining the data is to copy and paste the values from your browser into a text editor of your choice. Save it in the Datasets directory, which is found at the root of this project, with the filename example_air_passengers.csv.
#
# Alternatively, run the code below.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/facebook/prophet/main/examples/example_air_passengers.csv"
df = pd.read_csv(url)
df.to_csv("../datasets/example_air_passengers.csv", index=False)

# %% [markdown]
# ## Data set synopsis
# The air passengers dataset is a monthly timeseries representing the number of US air passengers collected between January 1949 and December 1960.

# %% [markdown]
# ## Check that you can load the data

# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/example_air_passengers.csv',
                parse_dates=['ds'],
                index_col=['ds'])

# %%
df.head()
# Out:
#               y
# ds
# 1949-01-01  112
# 1949-02-01  118
# 1949-03-01  132
# 1949-04-01  129
# 1949-05-01  121

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='ds'>
